# %% [markdown]
# <a href="https://colab.research.google.com/github/Mr-Jhon/psl-net-thesis/blob/main/00_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("PSL-Net Thesis")
# Out:
# PSL-Net Thesis
