# %% [markdown]
# <a href="https://colab.research.google.com/github/Mr-Jhon/psl-net-thesis/blob/main/notebooks/00_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

print(torch.cuda.is_available())
# Out:
# True

# %%
print(torch.cuda.get_device_name(0))
# Out:
# Tesla T4

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

PROJECT_DIR = "/content/drive/MyDrive/PSL-Net"

folders = [
    "dataset",
    "weights",
    "outputs",
    "logs"
]

for folder in folders:
    os.makedirs(
        os.path.join(PROJECT_DIR, folder),
        exist_ok=True
    )

print("Folder selesai dibuat")
# Out:
# Folder selesai dibuat

# %%
os.listdir(PROJECT_DIR)
# Out:
# ['dataset', 'weights', 'outputs', 'logs']

# %%
# !pip install albumentations

# %%
# !pip install timm

# %%
# !pip install onnx
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 90.8 MB/s eta 0:00:00
# ...

# %%
# !pip install onnxruntime
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.7/18.7 MB 96.9 MB/s eta 0:00:00
# ...

# %%
# !pip install tqdm

# %%
# !pip install opencv-python

# %%
import torch
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from tqdm import tqdm

print("Semua library berhasil diimport.")
# Out:
# Semua library berhasil diimport.

# %%
import sys

print("Python :", sys.version)
print("PyTorch :", torch.__version__)
print("CUDA :", torch.version.cuda)
# Out:
# Python : 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# PyTorch : 2.11.0+cu128
# CUDA : 12.8

# %%
import os

PROJECT_DIR = "/content/drive/MyDrive/PSL-Net"

DATASET_DIR = os.path.join(PROJECT_DIR, "dataset")
WEIGHTS_DIR = os.path.join(PROJECT_DIR, "weights")
OUTPUT_DIR = os.path.join(PROJECT_DIR, "outputs")
LOG_DIR = os.path.join(PROJECT_DIR, "logs")

# %%
print(DATASET_DIR)
print(WEIGHTS_DIR)
print(OUTPUT_DIR)
print(LOG_DIR)
# Out:
# /content/drive/MyDrive/PSL-Net/dataset
# /content/drive/MyDrive/PSL-Net/weights
# /content/drive/MyDrive/PSL-Net/outputs
# /content/drive/MyDrive/PSL-Net/logs
